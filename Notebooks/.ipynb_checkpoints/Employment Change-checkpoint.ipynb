# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import objects as so

# %%
# d = {"industry 1": pd.Series(original.industry1.unique()), 
#      "industry 2": pd.Series(original.industry2.unique()),
#      "industry 3": pd.Series(original.industry3.unique())
#     }
# unique = pd.DataFrame(data=d)
# unique.to_csv("Industry_Details.csv")

# %%
original = pd.read_csv("../Datasets/mrsd_4_annl_emp_chg_by_ind_14032022.csv")
df = original.drop(["industry1", "industry3"], axis=1).rename(columns = {"year":"Year", "industry2":"Industry", "employment_change":"Change"})
# df[['Year','Quarter']] = df.Year.str.split("-", expand=True)

# %%
# df = df.loc[(df.Industry=="food, beverages and tobacco") & (df.Change != "-")].reset_index(drop=True)
df = df.replace("-", 0)

# %%
df
# Out:
#      Year                                 Industry Change
# 0    1991                                   others   -0.1
# 1    1991                             construction   17.7
# 2    1991              food, beverages and tobacco    0.1
# 3    1991              textile and wearing apparel   -2.4
# 4    1991            paper products and publishing    0.8
# ..    ...                                      ...    ...
# 873  2021      administrative and support services    5.4
# 874  2021  community, social and personal services    1.5
# 875  2021  community, social and personal services   10.5
# 876  2021  community, social and personal services     -2
# 877  2021  community, social and personal services    1.3
#
# [878 rows x 3 columns]

# %%
df.Year = df.Year.astype(int)
df.Industry = df.Industry.astype(str)
df.Change = df.Change.astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      878 non-null    int64
#  1   Industry  878 non-null    object
#  2   Change    878 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 20.7+ KB

# %%
df= df.loc[(df.Year >= 2019) & (df.Year < 2021)]
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      64 non-null     int64
#  1   Industry  64 non-null     object
#  2   Change    64 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
plt.figure(figsize = (15,8))
sns.set_palette("Paired", 10)
sns.barplot(data=df, x="Year", y="Change", hue="Industry")

plt.show()

# %%
df
# Out:
#     Year                                         Industry  Change
# 0   2019                                           others    -0.1
# 1   2019                                     construction    12.6
# 2   2019                      food, beverages and tobacco     1.9
# 3   2019   paper / rubber / plastic products and printing    -1.1
# 4   2019  petroleum, chemical and pharmaceutical products     0.6
# ..   ...                                              ...     ...
# 59  2020              administrative and support services    -9.4
# 60  2020          community, social and personal services     8.1
# 61  2020          community, social and personal services     5.3
# 62  2020          community, social and personal services   -14.4
# 63  2020          community, social and personal services   -17.5
#
# [64 rows x 3 columns]
